# %%
import pandas as pd
from sodapy import Socrata

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.consumerfinance.gov", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("jhzv-w97w", limit=2000)

# %%
# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)

df= df[['complaint_id', 'issue']]

# %%
df.head(5)
# Out:
#   complaint_id                                     issue
# 0      2556983         Attempts to collect debt not owed
# 1      2383241     Cont'd attempts collect debt not owed
# 2      2532647            Trouble during payment process
# 3      2371574  Loan servicing, payments, escrow account
# 4      2432049                  Deposits and withdrawals

# %%
df.rename(columns={'complaint_id':'CASE_NUMBER','issue':'DETAILED_DESCRIPTION'})
# Out:
#      CASE_NUMBER                               DETAILED_DESCRIPTION
# 0        2556983                  Attempts to collect debt not owed
# 1        2383241              Cont'd attempts collect debt not owed
# 2        2532647                     Trouble during payment process
# 3        2371574           Loan servicing, payments, escrow account
# 4        2432049                           Deposits and withdrawals
# 5        2556286                        Improper use of your report
# 6        2416625                           Deposits and withdrawals
# 7        2423410                                          Other fee
# 8        2475212               Incorrect information on your report
# 9        2417442                           Deposits and withdrawals
# 10       2427124            Account opening, closing, or management
# 11       2440707            Account opening, closing, or management
# 12       2501717                         Struggling to pay mortgage
# 13       2570879                         Managing the loan or lease
# 14       2567772                              Communication tactics
# 15       2534292               Incorrect information on your report
# 16       2377534           Making/receiving payments, sending money
# 17       2500200                     Trouble during payment process
# 18       2564784               Incorrect information on your report
# 19       2559919                     Trouble during payment process
# 20       2571925               Incorrect information on your report
# 21       2412744                         Lost or stolen money order
# 22       2425815            Account opening, closing, or management
# 23       2561966                                Managing an account
# 24       2561030               Incorrect information on your report
# 25       2389782                    Disclosure verification of debt
# 26       1706577                    Disclosure verification of debt
# 27       2561575  Took or threatened to take negative or legal a...
# 28       2561322                              Communication tactics
# 29       2420218                         Managing the loan or lease
# ...          ...                                                ...
# 1970     2436245            Account opening, closing, or management
# 1971     2386699             Incorrect information on credit report
# 1972     2467931             Problem caused by your funds being low
# 1973     2439935                     Credit decision / Underwriting
# 1974     2417911              Problems caused by my funds being low
# 1975     2271684           Loan servicing, payments, escrow account
# 1976     2387927           Loan modification,collection,foreclosure
# 1977     2476379               Incorrect information on your report
# 1978     2389440                Problems when you are unable to pay
# 1979     2375290                 Dealing with my lender or servicer
# 1980     2469211                                Managing an account
# 1981     2388646                Improper contact or sharing of info
# 1982     2435925             Incorrect information on credit report
# 1983     2348514              Cont'd attempts collect debt not owed
# 1984     2445572           Credit reporting company's investigation
# 1985     2421378           Credit reporting company's investigation
# 1986     2467901                     Trouble during payment process
# 1987     2480260                        Improper use of your report
# 1988     2426745             Incorrect information on credit report
# 1989     2467282               Incorrect information on your report
# 1990     2483836                  Attempts to collect debt not owed
# 1991     2433270                    Disclosure verification of debt
# 1992     2471308                        Improper use of your report
# 1993     2390776           Loan servicing, payments, escrow account
# 1994     2472981               Incorrect information on your report
# 1995     2423229             Incorrect information on credit report
# 1996     2567431                      Struggling to repay your loan
# 1997     2404186           Credit reporting company's investigation
# 1998     2397947             Incorrect information on credit report
# 1999     2466577                                Managing an account
#
# [2000 rows x 2 columns]

# %%
df.to_csv('data/CODA_Export.csv')

# %%
CODA_export_file = pd.read_csv('data/CODA_Export.csv')

# %%
CODA_export_file.head(3)
# Out:
#    Unnamed: 0  complaint_id                                  issue
# 0           0       2556983      Attempts to collect debt not owed
# 1           1       2383241  Cont'd attempts collect debt not owed
# 2           2       2532647         Trouble during payment process
